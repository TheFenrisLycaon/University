# %% [markdown]
# # ****Exploratory Data Analysis****
#
# * EDA is simply data analysis techniqes to understand teh **various aspects of the data**.
#
# * **Prepration of the clean data** is the main aim of EDA.
#
# * Data should be free from Redundancies, null values , extreme values, missing values *etc.*
#
# * These things in the data may effect the model training and ultimately it will effect the performance of the trained model.
#
# * Before going on to the more complex procedures in the **data processing lifecycle**, it is necessary to come to a conclusion with the data or just draw some **conclusive insights** from the data.

# %% [markdown]
# **EDA works in two steps**
#
# 1. To identify the faulty points in the data, so that all the problmes in the data be removed
# 2. The understands the the relationship between the variables which gives us the wider prespective on data.
#
# Ultimately it helps us build on it by utilizing the relationship between the variables.

# %% [markdown]
# **Steps involved in EDA**
#
# 1. To understand the variables in the dataset. (type of the data points, size of the data, number of input variables, number of output variables *etc*
# 2. Clean the data from redundancies (irregularities in the data, outliers, NaN values, missing values *etc. *)
# 3. Analysis of the relationship between the variables

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('./Marketing_Analysis.csv')
data.shape
# Out:
# /home/fenris/.condahome/envs/Uni/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3229: DtypeWarning: Columns (0,1,2,3,11,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (45213, 19)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45213 entries, 0 to 45212
# Data columns (total 19 columns):
# banking marketing    45213 non-null object
# Unnamed: 1           45192 non-null object
# Unnamed: 2           45213 non-null object
# Unnamed: 3           45212 non-null object
# Unnamed: 4           45213 non-null object
# Unnamed: 5           45212 non-null object
# Unnamed: 6           45213 non-null object
# Unnamed: 7           45212 non-null object
# Unnamed: 8           45213 non-null object
# Unnamed: 9           45212 non-null object
# Unnamed: 10          45213 non-null object
# Unnamed: 11          45212 non-null object
# Unnamed: 12          45163 non-null object
# Unnamed: 13          45213 non-null object
# Unnamed: 14          45212 non-null object
# Unnamed: 15          45212 non-null object
# Unnamed: 16          45212 non-null object
# Unnamed: 17          45213 non-null object
# Unnamed: 18          45183 non-null object
# dtypes: object(19)
# memory usage: 6.6+ MB

# %%
data.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
#                                    Unnamed: 6 Unnamed: 7  \
# 0  particular customer before targeted or not        NaN
# 1                                    targeted    default
# 2                                         yes         no
# 3                                         yes         no
# 4                                         yes         no
#
#                            Unnamed: 8 Unnamed: 9   Unnamed: 10 Unnamed: 11  \
# 0  Loan types: loans or housing loans        NaN  Contact type         NaN
# 1                             housing       loan       contact         day
# 2                                 yes         no       unknown           5
# 3                                 yes         no       unknown           5
# 4                                 yes        yes       unknown           5
#
#         Unnamed: 12       Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0  month of contact  duration of call         NaN         NaN         NaN
# 1             month          duration    campaign       pdays    previous
# 2         may, 2017           261 sec           1          -1           0
# 3         may, 2017           151 sec           1          -1           0
# 4         may, 2017            76 sec           1          -1           0
#
#                    Unnamed: 17                              Unnamed: 18
# 0  outcome of previous contact  response of customer after call happned
# 1                     poutcome                                 response
# 2                      unknown                                       no
# 3                      unknown                                       no
# 4                      unknown                                       no

# %%
data .tail()
# Out:
#       banking marketing Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 45208             45207         51      60000        825    married
# 45209             45208         71      55000       1729   divorced
# 45210             45209         72      55000       5715    married
# 45211             45210         57      20000        668    married
# 45212             45211         37     120000       2971    married
#
#                    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 45208     technician,tertiary        yes         no         no         no
# 45209         retired,primary        yes         no         no         no
# 45210       retired,secondary        yes         no         no         no
# 45211   blue-collar,secondary        yes         no         no         no
# 45212  entrepreneur,secondary        yes         no         no         no
#
#       Unnamed: 10 Unnamed: 11 Unnamed: 12           Unnamed: 13 Unnamed: 14  \
# 45208    cellular          17   nov, 2017  16.2833333333333 min           3
# 45209    cellular          17   nov, 2017               7.6 min           2
# 45210    cellular          17   nov, 2017  18.7833333333333 min           5
# 45211   telephone          17   nov, 2017  8.46666666666667 min           4
# 45212    cellular          17   nov, 2017  6.01666666666667 min           2
#
#       Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 45208          -1           0     unknown         yes
# 45209          -1           0     unknown         yes
# 45210         184           3     success         yes
# 45211          -1           0     unknown          no
# 45212         188          11       other          no

# %%
data
# Out:
#           banking marketing Unnamed: 1                    Unnamed: 2  \
# 0      customer id and age.        NaN  Customer salary and balance.
# 1                customerid        age                        salary
# 2                         1         58                        100000
# 3                         2         44                         60000
# 4                         3         33                        120000
# 5                         4         47                         20000
# 6                         5         33                             0
# 7                         6         35                        100000
# 8                         7         28                        100000
# 9                         8         42                        120000
# 10                        9         58                         55000
# 11                       10         43                         60000
# 12                       11         41                         50000
# 13                       12         29                         50000
# 14                       13         53                         60000
# 15                       14         58                         60000
# 16                       15         57                         70000
# 17                       16         51                         55000
# 18                       17         45                         50000
# 19                       18         57                         20000
# 20                       19         60                         55000
# 21                       20         33                         70000
# 22                       21         28                         20000
# 23                       22         56                        100000
# 24                       23         32                         20000
# 25                       24         25                         70000
# 26                       25         40                         55000
# 27                       26         44                         50000
# 28                       27         39                        100000
# 29                       28         52                        120000
# ...                     ...        ...                           ...
# 45183                 45182         46                         20000
# 45184                 45183         34                         60000
# 45185                 45184         70                         55000
# 45186                 45185         63                         55000
# 45187                 45186         60                         70000
# 45188                 45187         59                             0
# 45189                 45188         32                         70000
# 45190                 45189         29                        100000
# 45191                 45190         25                         70000
# 45192                 45191         32                         20000
# 45193                 45192         75                         55000
# 45194                 45193         29                        100000
# 45195                 45194         28                         60000
# 45196                 45195         59                        100000
# 45197                 45196         68                         55000
# 45198                 45197         25                          4000
# 45199                 45198         36                        100000
# 45200                 45199         37                        100000
# 45201                 45200         34                         20000
# 45202                 45201         38                         60000
# 45203                 45202         53                        100000
# 45204                 45203         34                         50000
# 45205                 45204         23                          4000
# 45206                 45205         73                         55000
# 45207                 45206         25                         60000
# 45208                 45207         51                         60000
# 45209                 45208         71                         55000
# 45210                 45209         72                         55000
# 45211                 45210         57                         20000
# 45212                 45211         37                        120000
#
#       Unnamed: 3                                         Unnamed: 4  \
# 0            NaN  Customer marital status and job with education...
# 1        balance                                            marital
# 2           2143                                            married
# 3             29                                             single
# 4              2                                            married
# 5           1506                                            married
# 6              1                                             single
# 7            231                                            married
# 8            447                                             single
# 9              2                                           divorced
# 10           121                                            married
# 11           593                                             single
# 12           270                                           divorced
# 13           390                                             single
# 14             6                                            married
# 15            71                                            married
# 16           162                                            married
# 17           229                                            married
# 18            13                                             single
# 19            52                                            married
# 20            60                                            married
# 21             0                                            married
# 22           723                                            married
# 23           779                                            married
# 24            23                                             single
# 25            50                                            married
# 26             0                                            married
# 27          -372                                            married
# 28           255                                             single
# 29           113                                            married
# ...          ...                                                ...
# 45183       6879                                            married
# 45184        133                                            married
# 45185        324                                            married
# 45186       1495                                            married
# 45187       4256                                            married
# 45188       1500                                            married
# 45189       1168                                             single
# 45190        703                                             single
# 45191        199                                             single
# 45192        136                                            married
# 45193       3810                                           divorced
# 45194        765                                             single
# 45195        159                                             single
# 45196        138                                            married
# 45197       1146                                            married
# 45198        358                                             single
# 45199       1511                                             single
# 45200       1428                                            married
# 45201       1475                                             single
# 45202        557                                            married
# 45203        583                                            married
# 45204        557                                             single
# 45205        113                                             single
# 45206       2850                                            married
# 45207        505                                             single
# 45208        825                                            married
# 45209       1729                                           divorced
# 45210       5715                                            married
# 45211        668                                            married
# 45212       2971                                            married
#
#                    Unnamed: 5                                  Unnamed: 6  \
# 0                         NaN  particular customer before targeted or not
# 1                      jobedu                                    targeted
# 2         management,tertiary                                         yes
# 3        technician,secondary                                         yes
# 4      entrepreneur,secondary                                         yes
# 5         blue-collar,unknown                                          no
# 6             unknown,unknown                                          no
# 7         management,tertiary                                         yes
# 8         management,tertiary                                          no
# 9       entrepreneur,tertiary                                          no
# 10            retired,primary                                         yes
# 11       technician,secondary                                         yes
# 12           admin.,secondary                                         yes
# 13           admin.,secondary                                         yes
# 14       technician,secondary                                         yes
# 15         technician,unknown                                          no
# 16         services,secondary                                         yes
# 17            retired,primary                                         yes
# 18             admin.,unknown                                          no
# 19        blue-collar,primary                                         yes
# 20            retired,primary                                         yes
# 21         services,secondary                                         yes
# 22      blue-collar,secondary                                         yes
# 23        management,tertiary                                         yes
# 24        blue-collar,primary                                         yes
# 25         services,secondary                                         yes
# 26            retired,primary                                         yes
# 27           admin.,secondary                                         yes
# 28        management,tertiary                                          no
# 29     entrepreneur,secondary                                         yes
# ...                       ...                                         ...
# 45183   blue-collar,secondary                                         yes
# 45184    technician,secondary                                         yes
# 45185         retired,primary                                         yes
# 45186       retired,secondary                                         yes
# 45187       services,tertiary                                         yes
# 45188         unknown,unknown                                          no
# 45189      services,secondary                                         yes
# 45190    management,secondary                                         yes
# 45191      services,secondary                                         yes
# 45192   blue-collar,secondary                                         yes
# 45193        retired,tertiary                                          no
# 45194     management,tertiary                                          no
# 45195  self-employed,tertiary                                          no
# 45196     management,tertiary                                         yes
# 45197       retired,secondary                                         yes
# 45198       student,secondary                                         yes
# 45199    management,secondary                                         yes
# 45200     management,tertiary                                         yes
# 45201   blue-collar,secondary                                         yes
# 45202    technician,secondary                                         yes
# 45203     management,tertiary                                         yes
# 45204        admin.,secondary                                         yes
# 45205        student,tertiary                                          no
# 45206       retired,secondary                                         yes
# 45207    technician,secondary                                         yes
# 45208     technician,tertiary                                         yes
# 45209         retired,primary                                         yes
# 45210       retired,secondary                                         yes
# 45211   blue-collar,secondary                                         yes
# 45212  entrepreneur,secondary                                         yes
#
#       Unnamed: 7                          Unnamed: 8 Unnamed: 9   Unnamed: 10  \
# 0            NaN  Loan types: loans or housing loans        NaN  Contact type
# 1        default                             housing       loan       contact
# 2             no                                 yes         no       unknown
# 3             no                                 yes         no       unknown
# 4             no                                 yes        yes       unknown
# 5             no                                 yes         no       unknown
# 6             no                                  no         no       unknown
# 7             no                                 yes         no       unknown
# 8             no                                 yes        yes       unknown
# 9            yes                                 yes         no       unknown
# 10            no                                 yes         no       unknown
# 11            no                                 yes         no       unknown
# 12            no                                 yes         no       unknown
# 13            no                                 yes         no       unknown
# 14            no                                 yes         no       unknown
# 15            no                                 yes         no       unknown
# 16            no                                 yes         no       unknown
# 17            no                                 yes         no       unknown
# 18            no                                 yes         no       unknown
# 19            no                                 yes         no       unknown
# 20            no                                 yes         no       unknown
# 21            no                                 yes         no       unknown
# 22            no                                 yes        yes       unknown
# 23            no                                 yes         no       unknown
# 24            no                                 yes        yes       unknown
# 25            no                                 yes         no       unknown
# 26            no                                 yes        yes       unknown
# 27            no                                 yes         no       unknown
# 28            no                                 yes         no       unknown
# 29            no                                 yes        yes       unknown
# ...          ...                                 ...        ...           ...
# 45183         no                                  no         no      cellular
# 45184         no                                  no         no      cellular
# 45185         no                                  no         no      cellular
# 45186         no                                  no         no      cellular
# 45187         no                                 yes         no      cellular
# 45188         no                                  no         no      cellular
# 45189         no                                 yes         no      cellular
# 45190         no                                 yes         no      cellular
# 45191         no                                  no         no      cellular
# 45192         no                                  no         no      cellular
# 45193         no                                 yes         no      cellular
# 45194         no                                  no         no      cellular
# 45195         no                                  no         no      cellular
# 45196         no                                 yes        yes      cellular
# 45197         no                                  no         no      cellular
# 45198         no                                  no         no      cellular
# 45199         no                                 yes         no      cellular
# 45200         no                                  no         no      cellular
# 45201         no                                 yes         no      cellular
# 45202         no                                 yes         no      cellular
# 45203         no                                  no         no      cellular
# 45204         no                                  no         no      cellular
# 45205         no                                  no         no      cellular
# 45206         no                                  no         no      cellular
# 45207         no                                  no        yes      cellular
# 45208         no                                  no         no      cellular
# 45209         no                                  no         no      cellular
# 45210         no                                  no         no      cellular
# 45211         no                                  no         no     telephone
# 45212         no                                  no         no      cellular
#
#       Unnamed: 11       Unnamed: 12           Unnamed: 13 Unnamed: 14  \
# 0             NaN  month of contact      duration of call         NaN
# 1             day             month              duration    campaign
# 2               5         may, 2017               261 sec           1
# 3               5         may, 2017               151 sec           1
# 4               5         may, 2017                76 sec           1
# 5               5         may, 2017                92 sec           1
# 6               5         may, 2017               198 sec           1
# 7               5         may, 2017               139 sec           1
# 8               5         may, 2017               217 sec           1
# 9               5         may, 2017               380 sec           1
# 10              5         may, 2017                50 sec           1
# 11              5         may, 2017                55 sec           1
# 12              5         may, 2017               222 sec           1
# 13              5         may, 2017               137 sec           1
# 14              5         may, 2017               517 sec           1
# 15              5         may, 2017                71 sec           1
# 16              5         may, 2017               174 sec           1
# 17              5         may, 2017               353 sec           1
# 18              5         may, 2017                98 sec           1
# 19              5         may, 2017                38 sec           1
# 20              5         may, 2017               219 sec           1
# 21              5         may, 2017                54 sec           1
# 22              5         may, 2017               262 sec           1
# 23              5         may, 2017               164 sec           1
# 24              5         may, 2017               160 sec           1
# 25              5         may, 2017               342 sec           1
# 26              5         may, 2017               181 sec           1
# 27              5         may, 2017               172 sec           1
# 28              5         may, 2017               296 sec           1
# 29              5         may, 2017               127 sec           1
# ...           ...               ...                   ...         ...
# 45183          15         nov, 2017  1.23333333333333 min           2
# 45184          15         nov, 2017  6.68333333333333 min           2
# 45185          15         nov, 2017               1.3 min           1
# 45186          16         nov, 2017               2.3 min           1
# 45187          16         nov, 2017  3.33333333333333 min           1
# 45188          16         nov, 2017  4.66666666666667 min           1
# 45189          16         nov, 2017              6.85 min           1
# 45190          16         nov, 2017  3.93333333333333 min           1
# 45191          16         nov, 2017  2.88333333333333 min           1
# 45192          16         nov, 2017  3.43333333333333 min           1
# 45193          16         nov, 2017  4.36666666666667 min           1
# 45194          16         nov, 2017  3.96666666666667 min           1
# 45195          16         nov, 2017  7.48333333333333 min           2
# 45196          16         nov, 2017               2.7 min           2
# 45197          16         nov, 2017  3.53333333333333 min           1
# 45198          16         nov, 2017               5.5 min           1
# 45199          16         nov, 2017               4.5 min           1
# 45200          16         nov, 2017              5.55 min           2
# 45201          16         nov, 2017  19.4333333333333 min           3
# 45202          16         nov, 2017  25.9333333333333 min           4
# 45203          17         nov, 2017  3.76666666666667 min           1
# 45204          17         nov, 2017  3.73333333333333 min           1
# 45205          17         nov, 2017  4.43333333333333 min           1
# 45206          17         nov, 2017                 5 min           1
# 45207          17         nov, 2017  6.43333333333333 min           2
# 45208          17         nov, 2017  16.2833333333333 min           3
# 45209          17         nov, 2017               7.6 min           2
# 45210          17         nov, 2017  18.7833333333333 min           5
# 45211          17         nov, 2017  8.46666666666667 min           4
# 45212          17         nov, 2017  6.01666666666667 min           2
#
#       Unnamed: 15 Unnamed: 16                  Unnamed: 17  \
# 0             NaN         NaN  outcome of previous contact
# 1           pdays    previous                     poutcome
# 2              -1           0                      unknown
# 3              -1           0                      unknown
# 4              -1           0                      unknown
# 5              -1           0                      unknown
# 6              -1           0                      unknown
# 7              -1           0                      unknown
# 8              -1           0                      unknown
# 9              -1           0                      unknown
# 10             -1           0                      unknown
# 11             -1           0                      unknown
# 12             -1           0                      unknown
# 13             -1           0                      unknown
# 14             -1           0                      unknown
# 15             -1           0                      unknown
# 16             -1           0                      unknown
# 17             -1           0                      unknown
# 18             -1           0                      unknown
# 19             -1           0                      unknown
# 20             -1           0                      unknown
# 21             -1           0                      unknown
# 22             -1           0                      unknown
# 23             -1           0                      unknown
# 24             -1           0                      unknown
# 25             -1           0                      unknown
# 26             -1           0                      unknown
# 27             -1           0                      unknown
# 28             -1           0                      unknown
# 29             -1           0                      unknown
# ...           ...         ...                          ...
# 45183         118           3                      failure
# 45184         187           5                      success
# 45185          96           7                      success
# 45186          22           5                      success
# 45187          92           4                      success
# 45188         104           2                      failure
# 45189          -1           0                      unknown
# 45190         550           2                      success
# 45191          92           5                      failure
# 45192         188           3                      success
# 45193         183           1                      failure
# 45194          -1           0                      unknown
# 45195          33           4                      success
# 45196         187           5                      failure
# 45197         187           6                      success
# 45198          -1           0                      unknown
# 45199          -1           0                      unknown
# 45200          -1           0                      unknown
# 45201         530          12                        other
# 45202          -1           0                      unknown
# 45203         184           4                      success
# 45204          -1           0                      unknown
# 45205          -1           0                      unknown
# 45206          40           8                      failure
# 45207          -1           0                      unknown
# 45208          -1           0                      unknown
# 45209          -1           0                      unknown
# 45210         184           3                      success
# 45211          -1           0                      unknown
# 45212         188          11                        other
#
#                                    Unnamed: 18
# 0      response of customer after call happned
# 1                                     response
# 2                                           no
# 3                                           no
# 4                                           no
# 5                                           no
# 6                                           no
# 7                                           no
# 8                                           no
# 9                                           no
# 10                                          no
# 11                                          no
# 12                                          no
# 13                                          no
# 14                                          no
# 15                                          no
# 16                                          no
# 17                                          no
# 18                                          no
# 19                                          no
# 20                                          no
# 21                                          no
# 22                                          no
# 23                                          no
# 24                                          no
# 25                                          no
# 26                                          no
# 27                                          no
# 28                                          no
# 29                                          no
# ...                                        ...
# 45183                                       no
# 45184                                      yes
# 45185                                       no
# 45186                                       no
# 45187                                      yes
# 45188                                       no
# 45189                                      yes
# 45190                                      yes
# 45191                                       no
# 45192                                      yes
# 45193                                      yes
# 45194                                      yes
# 45195                                      yes
# 45196                                       no
# 45197                                      yes
# 45198                                      yes
# 45199                                      yes
# 45200                                       no
# 45201                                       no
# 45202                                      yes
# 45203                                      yes
# 45204                                      yes
# 45205                                      yes
# 45206                                      yes
# 45207                                      yes
# 45208                                      yes
# 45209                                      yes
# 45210                                      yes
# 45211                                       no
# 45212                                       no
#
# [45213 rows x 19 columns]

# %%
data.describe()
# Out:
#        banking marketing Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# count              45213      45192      45213      45212      45213
# unique             45213        145         24      10335          5
# top                11648         32      20000          0    married
# freq                   1       1509       7290       2767      27214
#
#                  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# count                 45212      45213      45212      45213      45212
# unique                   49          4          3          4          3
# top     management,tertiary        yes         no        yes         no
# freq                   7801      37091      44396      25130      37967
#
#        Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# count        45213       45212       45163       45213       45212
# unique           5          63          14        2648          67
# top       cellular          20   may, 2017     1.5 min           1
# freq         29285        2030       13747         138       11502
#
#        Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# count        45212       45212       45213       45183
# unique         837          72           6           4
# top             -1           0     unknown          no
# freq         30277       30277       36959       39894

# %%
data_new=data.iloc[2:,:]

# %%
data_new.shape
# Out:
# (45211, 19)

# %%
data_new
# Out:
#       banking marketing Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2                     1         58     100000       2143    married
# 3                     2         44      60000         29     single
# 4                     3         33     120000          2    married
# 5                     4         47      20000       1506    married
# 6                     5         33          0          1     single
# 7                     6         35     100000        231    married
# 8                     7         28     100000        447     single
# 9                     8         42     120000          2   divorced
# 10                    9         58      55000        121    married
# 11                   10         43      60000        593     single
# 12                   11         41      50000        270   divorced
# 13                   12         29      50000        390     single
# 14                   13         53      60000          6    married
# 15                   14         58      60000         71    married
# 16                   15         57      70000        162    married
# 17                   16         51      55000        229    married
# 18                   17         45      50000         13     single
# 19                   18         57      20000         52    married
# 20                   19         60      55000         60    married
# 21                   20         33      70000          0    married
# 22                   21         28      20000        723    married
# 23                   22         56     100000        779    married
# 24                   23         32      20000         23     single
# 25                   24         25      70000         50    married
# 26                   25         40      55000          0    married
# 27                   26         44      50000       -372    married
# 28                   27         39     100000        255     single
# 29                   28         52     120000        113    married
# 30                   29         46     100000       -246     single
# 31                   30         36      60000        265     single
# ...                 ...        ...        ...        ...        ...
# 45183             45182         46      20000       6879    married
# 45184             45183         34      60000        133    married
# 45185             45184         70      55000        324    married
# 45186             45185         63      55000       1495    married
# 45187             45186         60      70000       4256    married
# 45188             45187         59          0       1500    married
# 45189             45188         32      70000       1168     single
# 45190             45189         29     100000        703     single
# 45191             45190         25      70000        199     single
# 45192             45191         32      20000        136    married
# 45193             45192         75      55000       3810   divorced
# 45194             45193         29     100000        765     single
# 45195             45194         28      60000        159     single
# 45196             45195         59     100000        138    married
# 45197             45196         68      55000       1146    married
# 45198             45197         25       4000        358     single
# 45199             45198         36     100000       1511     single
# 45200             45199         37     100000       1428    married
# 45201             45200         34      20000       1475     single
# 45202             45201         38      60000        557    married
# 45203             45202         53     100000        583    married
# 45204             45203         34      50000        557     single
# 45205             45204         23       4000        113     single
# 45206             45205         73      55000       2850    married
# 45207             45206         25      60000        505     single
# 45208             45207         51      60000        825    married
# 45209             45208         71      55000       1729   divorced
# 45210             45209         72      55000       5715    married
# 45211             45210         57      20000        668    married
# 45212             45211         37     120000       2971    married
#
#                    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 2         management,tertiary        yes         no        yes         no
# 3        technician,secondary        yes         no        yes         no
# 4      entrepreneur,secondary        yes         no        yes        yes
# 5         blue-collar,unknown         no         no        yes         no
# 6             unknown,unknown         no         no         no         no
# 7         management,tertiary        yes         no        yes         no
# 8         management,tertiary         no         no        yes        yes
# 9       entrepreneur,tertiary         no        yes        yes         no
# 10            retired,primary        yes         no        yes         no
# 11       technician,secondary        yes         no        yes         no
# 12           admin.,secondary        yes         no        yes         no
# 13           admin.,secondary        yes         no        yes         no
# 14       technician,secondary        yes         no        yes         no
# 15         technician,unknown         no         no        yes         no
# 16         services,secondary        yes         no        yes         no
# 17            retired,primary        yes         no        yes         no
# 18             admin.,unknown         no         no        yes         no
# 19        blue-collar,primary        yes         no        yes         no
# 20            retired,primary        yes         no        yes         no
# 21         services,secondary        yes         no        yes         no
# 22      blue-collar,secondary        yes         no        yes        yes
# 23        management,tertiary        yes         no        yes         no
# 24        blue-collar,primary        yes         no        yes        yes
# 25         services,secondary        yes         no        yes         no
# 26            retired,primary        yes         no        yes        yes
# 27           admin.,secondary        yes         no        yes         no
# 28        management,tertiary         no         no        yes         no
# 29     entrepreneur,secondary        yes         no        yes        yes
# 30       management,secondary        yes         no        yes         no
# 31       technician,secondary        yes         no        yes        yes
# ...                       ...        ...        ...        ...        ...
# 45183   blue-collar,secondary        yes         no         no         no
# 45184    technician,secondary        yes         no         no         no
# 45185         retired,primary        yes         no         no         no
# 45186       retired,secondary        yes         no         no         no
# 45187       services,tertiary        yes         no        yes         no
# 45188         unknown,unknown         no         no         no         no
# 45189      services,secondary        yes         no        yes         no
# 45190    management,secondary        yes         no        yes         no
# 45191      services,secondary        yes         no         no         no
# 45192   blue-collar,secondary        yes         no         no         no
# 45193        retired,tertiary         no         no        yes         no
# 45194     management,tertiary         no         no         no         no
# 45195  self-employed,tertiary         no         no         no         no
# 45196     management,tertiary        yes         no        yes        yes
# 45197       retired,secondary        yes         no         no         no
# 45198       student,secondary        yes         no         no         no
# 45199    management,secondary        yes         no        yes         no
# 45200     management,tertiary        yes         no         no         no
# 45201   blue-collar,secondary        yes         no        yes         no
# 45202    technician,secondary        yes         no        yes         no
# 45203     management,tertiary        yes         no         no         no
# 45204        admin.,secondary        yes         no         no         no
# 45205        student,tertiary         no         no         no         no
# 45206       retired,secondary        yes         no         no         no
# 45207    technician,secondary        yes         no         no        yes
# 45208     technician,tertiary        yes         no         no         no
# 45209         retired,primary        yes         no         no         no
# 45210       retired,secondary        yes         no         no         no
# 45211   blue-collar,secondary        yes         no         no         no
# 45212  entrepreneur,secondary        yes         no         no         no
#
#       Unnamed: 10 Unnamed: 11 Unnamed: 12           Unnamed: 13 Unnamed: 14  \
# 2         unknown           5   may, 2017               261 sec           1
# 3         unknown           5   may, 2017               151 sec           1
# 4         unknown           5   may, 2017                76 sec           1
# 5         unknown           5   may, 2017                92 sec           1
# 6         unknown           5   may, 2017               198 sec           1
# 7         unknown           5   may, 2017               139 sec           1
# 8         unknown           5   may, 2017               217 sec           1
# 9         unknown           5   may, 2017               380 sec           1
# 10        unknown           5   may, 2017                50 sec           1
# 11        unknown           5   may, 2017                55 sec           1
# 12        unknown           5   may, 2017               222 sec           1
# 13        unknown           5   may, 2017               137 sec           1
# 14        unknown           5   may, 2017               517 sec           1
# 15        unknown           5   may, 2017                71 sec           1
# 16        unknown           5   may, 2017               174 sec           1
# 17        unknown           5   may, 2017               353 sec           1
# 18        unknown           5   may, 2017                98 sec           1
# 19        unknown           5   may, 2017                38 sec           1
# 20        unknown           5   may, 2017               219 sec           1
# 21        unknown           5   may, 2017                54 sec           1
# 22        unknown           5   may, 2017               262 sec           1
# 23        unknown           5   may, 2017               164 sec           1
# 24        unknown           5   may, 2017               160 sec           1
# 25        unknown           5   may, 2017               342 sec           1
# 26        unknown           5   may, 2017               181 sec           1
# 27        unknown           5   may, 2017               172 sec           1
# 28        unknown           5   may, 2017               296 sec           1
# 29        unknown           5   may, 2017               127 sec           1
# 30        unknown           5   may, 2017               255 sec           2
# 31        unknown           5   may, 2017               348 sec           1
# ...           ...         ...         ...                   ...         ...
# 45183    cellular          15   nov, 2017  1.23333333333333 min           2
# 45184    cellular          15   nov, 2017  6.68333333333333 min           2
# 45185    cellular          15   nov, 2017               1.3 min           1
# 45186    cellular          16   nov, 2017               2.3 min           1
# 45187    cellular          16   nov, 2017  3.33333333333333 min           1
# 45188    cellular          16   nov, 2017  4.66666666666667 min           1
# 45189    cellular          16   nov, 2017              6.85 min           1
# 45190    cellular          16   nov, 2017  3.93333333333333 min           1
# 45191    cellular          16   nov, 2017  2.88333333333333 min           1
# 45192    cellular          16   nov, 2017  3.43333333333333 min           1
# 45193    cellular          16   nov, 2017  4.36666666666667 min           1
# 45194    cellular          16   nov, 2017  3.96666666666667 min           1
# 45195    cellular          16   nov, 2017  7.48333333333333 min           2
# 45196    cellular          16   nov, 2017               2.7 min           2
# 45197    cellular          16   nov, 2017  3.53333333333333 min           1
# 45198    cellular          16   nov, 2017               5.5 min           1
# 45199    cellular          16   nov, 2017               4.5 min           1
# 45200    cellular          16   nov, 2017              5.55 min           2
# 45201    cellular          16   nov, 2017  19.4333333333333 min           3
# 45202    cellular          16   nov, 2017  25.9333333333333 min           4
# 45203    cellular          17   nov, 2017  3.76666666666667 min           1
# 45204    cellular          17   nov, 2017  3.73333333333333 min           1
# 45205    cellular          17   nov, 2017  4.43333333333333 min           1
# 45206    cellular          17   nov, 2017                 5 min           1
# 45207    cellular          17   nov, 2017  6.43333333333333 min           2
# 45208    cellular          17   nov, 2017  16.2833333333333 min           3
# 45209    cellular          17   nov, 2017               7.6 min           2
# 45210    cellular          17   nov, 2017  18.7833333333333 min           5
# 45211   telephone          17   nov, 2017  8.46666666666667 min           4
# 45212    cellular          17   nov, 2017  6.01666666666667 min           2
#
#       Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18
# 2              -1           0     unknown          no
# 3              -1           0     unknown          no
# 4              -1           0     unknown          no
# 5              -1           0     unknown          no
# 6              -1           0     unknown          no
# 7              -1           0     unknown          no
# 8              -1           0     unknown          no
# 9              -1           0     unknown          no
# 10             -1           0     unknown          no
# 11             -1           0     unknown          no
# 12             -1           0     unknown          no
# 13             -1           0     unknown          no
# 14             -1           0     unknown          no
# 15             -1           0     unknown          no
# 16             -1           0     unknown          no
# 17             -1           0     unknown          no
# 18             -1           0     unknown          no
# 19             -1           0     unknown          no
# 20             -1           0     unknown          no
# 21             -1           0     unknown          no
# 22             -1           0     unknown          no
# 23             -1           0     unknown          no
# 24             -1           0     unknown          no
# 25             -1           0     unknown          no
# 26             -1           0     unknown          no
# 27             -1           0     unknown          no
# 28             -1           0     unknown          no
# 29             -1           0     unknown          no
# 30             -1           0     unknown          no
# 31             -1           0     unknown          no
# ...           ...         ...         ...         ...
# 45183         118           3     failure          no
# 45184         187           5     success         yes
# 45185          96           7     success          no
# 45186          22           5     success          no
# 45187          92           4     success         yes
# 45188         104           2     failure          no
# 45189          -1           0     unknown         yes
# 45190         550           2     success         yes
# 45191          92           5     failure          no
# 45192         188           3     success         yes
# 45193         183           1     failure         yes
# 45194          -1           0     unknown         yes
# 45195          33           4     success         yes
# 45196         187           5     failure          no
# 45197         187           6     success         yes
# 45198          -1           0     unknown         yes
# 45199          -1           0     unknown         yes
# 45200          -1           0     unknown          no
# 45201         530          12       other          no
# 45202          -1           0     unknown         yes
# 45203         184           4     success         yes
# 45204          -1           0     unknown         yes
# 45205          -1           0     unknown         yes
# 45206          40           8     failure         yes
# 45207          -1           0     unknown         yes
# 45208          -1           0     unknown         yes
# 45209          -1           0     unknown         yes
# 45210         184           3     success         yes
# 45211          -1           0     unknown          no
# 45212         188          11       other          no
#
# [45211 rows x 19 columns]

# %%
data_again = pd.read_csv("./Marketing_Analysis.csv",skiprows = 2)
data_again
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# 5               6  35.0  100000      231   married     management,tertiary
# 6               7  28.0  100000      447    single     management,tertiary
# 7               8  42.0  120000        2  divorced   entrepreneur,tertiary
# 8               9  58.0   55000      121   married         retired,primary
# 9              10  43.0   60000      593    single    technician,secondary
# 10             11  41.0   50000      270  divorced        admin.,secondary
# 11             12  29.0   50000      390    single        admin.,secondary
# 12             13  53.0   60000        6   married    technician,secondary
# 13             14  58.0   60000       71   married      technician,unknown
# 14             15  57.0   70000      162   married      services,secondary
# 15             16  51.0   55000      229   married         retired,primary
# 16             17  45.0   50000       13    single          admin.,unknown
# 17             18  57.0   20000       52   married     blue-collar,primary
# 18             19  60.0   55000       60   married         retired,primary
# 19             20  33.0   70000        0   married      services,secondary
# 20             21  28.0   20000      723   married   blue-collar,secondary
# 21             22  56.0  100000      779   married     management,tertiary
# 22             23  32.0   20000       23    single     blue-collar,primary
# 23             24  25.0   70000       50   married      services,secondary
# 24             25  40.0   55000        0   married         retired,primary
# 25             26  44.0   50000     -372   married        admin.,secondary
# 26             27  39.0  100000      255    single     management,tertiary
# 27             28  52.0  120000      113   married  entrepreneur,secondary
# 28             29  46.0  100000     -246    single    management,secondary
# 29             30  36.0   60000      265    single    technician,secondary
# ...           ...   ...     ...      ...       ...                     ...
# 45181       45182  46.0   20000     6879   married   blue-collar,secondary
# 45182       45183  34.0   60000      133   married    technician,secondary
# 45183       45184  70.0   55000      324   married         retired,primary
# 45184       45185  63.0   55000     1495   married       retired,secondary
# 45185       45186  60.0   70000     4256   married       services,tertiary
# 45186       45187  59.0       0     1500   married         unknown,unknown
# 45187       45188  32.0   70000     1168    single      services,secondary
# 45188       45189  29.0  100000      703    single    management,secondary
# 45189       45190  25.0   70000      199    single      services,secondary
# 45190       45191  32.0   20000      136   married   blue-collar,secondary
# 45191       45192  75.0   55000     3810  divorced        retired,tertiary
# 45192       45193  29.0  100000      765    single     management,tertiary
# 45193       45194  28.0   60000      159    single  self-employed,tertiary
# 45194       45195  59.0  100000      138   married     management,tertiary
# 45195       45196  68.0   55000     1146   married       retired,secondary
# 45196       45197  25.0    4000      358    single       student,secondary
# 45197       45198  36.0  100000     1511    single    management,secondary
# 45198       45199  37.0  100000     1428   married     management,tertiary
# 45199       45200  34.0   20000     1475    single   blue-collar,secondary
# 45200       45201  38.0   60000      557   married    technician,secondary
# 45201       45202  53.0  100000      583   married     management,tertiary
# 45202       45203  34.0   50000      557    single        admin.,secondary
# 45203       45204  23.0    4000      113    single        student,tertiary
# 45204       45205  73.0   55000     2850   married       retired,secondary
# 45205       45206  25.0   60000      505    single    technician,secondary
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# 0          yes      no     yes   no    unknown    5  may, 2017
# 1          yes      no     yes   no    unknown    5  may, 2017
# 2          yes      no     yes  yes    unknown    5  may, 2017
# 3           no      no     yes   no    unknown    5  may, 2017
# 4           no      no      no   no    unknown    5  may, 2017
# 5          yes      no     yes   no    unknown    5  may, 2017
# 6           no      no     yes  yes    unknown    5  may, 2017
# 7           no     yes     yes   no    unknown    5  may, 2017
# 8          yes      no     yes   no    unknown    5  may, 2017
# 9          yes      no     yes   no    unknown    5  may, 2017
# 10         yes      no     yes   no    unknown    5  may, 2017
# 11         yes      no     yes   no    unknown    5  may, 2017
# 12         yes      no     yes   no    unknown    5  may, 2017
# 13          no      no     yes   no    unknown    5  may, 2017
# 14         yes      no     yes   no    unknown    5  may, 2017
# 15         yes      no     yes   no    unknown    5  may, 2017
# 16          no      no     yes   no    unknown    5  may, 2017
# 17         yes      no     yes   no    unknown    5  may, 2017
# 18         yes      no     yes   no    unknown    5  may, 2017
# 19         yes      no     yes   no    unknown    5  may, 2017
# 20         yes      no     yes  yes    unknown    5  may, 2017
# 21         yes      no     yes   no    unknown    5  may, 2017
# 22         yes      no     yes  yes    unknown    5  may, 2017
# 23         yes      no     yes   no    unknown    5  may, 2017
# 24         yes      no     yes  yes    unknown    5  may, 2017
# 25         yes      no     yes   no    unknown    5  may, 2017
# 26          no      no     yes   no    unknown    5  may, 2017
# 27         yes      no     yes  yes    unknown    5  may, 2017
# 28         yes      no     yes   no    unknown    5  may, 2017
# 29         yes      no     yes  yes    unknown    5  may, 2017
# ...        ...     ...     ...  ...        ...  ...        ...
# 45181      yes      no      no   no   cellular   15  nov, 2017
# 45182      yes      no      no   no   cellular   15  nov, 2017
# 45183      yes      no      no   no   cellular   15  nov, 2017
# 45184      yes      no      no   no   cellular   16  nov, 2017
# 45185      yes      no     yes   no   cellular   16  nov, 2017
# 45186       no      no      no   no   cellular   16  nov, 2017
# 45187      yes      no     yes   no   cellular   16  nov, 2017
# 45188      yes      no     yes   no   cellular   16  nov, 2017
# 45189      yes      no      no   no   cellular   16  nov, 2017
# 45190      yes      no      no   no   cellular   16  nov, 2017
# 45191       no      no     yes   no   cellular   16  nov, 2017
# 45192       no      no      no   no   cellular   16  nov, 2017
# 45193       no      no      no   no   cellular   16  nov, 2017
# 45194      yes      no     yes  yes   cellular   16  nov, 2017
# 45195      yes      no      no   no   cellular   16  nov, 2017
# 45196      yes      no      no   no   cellular   16  nov, 2017
# 45197      yes      no     yes   no   cellular   16  nov, 2017
# 45198      yes      no      no   no   cellular   16  nov, 2017
# 45199      yes      no     yes   no   cellular   16  nov, 2017
# 45200      yes      no     yes   no   cellular   16  nov, 2017
# 45201      yes      no      no   no   cellular   17  nov, 2017
# 45202      yes      no      no   no   cellular   17  nov, 2017
# 45203       no      no      no   no   cellular   17  nov, 2017
# 45204      yes      no      no   no   cellular   17  nov, 2017
# 45205      yes      no      no  yes   cellular   17  nov, 2017
# 45206      yes      no      no   no   cellular   17  nov, 2017
# 45207      yes      no      no   no   cellular   17  nov, 2017
# 45208      yes      no      no   no   cellular   17  nov, 2017
# 45209      yes      no      no   no  telephone   17  nov, 2017
# 45210      yes      no      no   no   cellular   17  nov, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 0                   261 sec         1     -1         0  unknown       no
# 1                   151 sec         1     -1         0  unknown       no
# 2                    76 sec         1     -1         0  unknown       no
# 3                    92 sec         1     -1         0  unknown       no
# 4                   198 sec         1     -1         0  unknown       no
# 5                   139 sec         1     -1         0  unknown       no
# 6                   217 sec         1     -1         0  unknown       no
# 7                   380 sec         1     -1         0  unknown       no
# 8                    50 sec         1     -1         0  unknown       no
# 9                    55 sec         1     -1         0  unknown       no
# 10                  222 sec         1     -1         0  unknown       no
# 11                  137 sec         1     -1         0  unknown       no
# 12                  517 sec         1     -1         0  unknown       no
# 13                   71 sec         1     -1         0  unknown       no
# 14                  174 sec         1     -1         0  unknown       no
# 15                  353 sec         1     -1         0  unknown       no
# 16                   98 sec         1     -1         0  unknown       no
# 17                   38 sec         1     -1         0  unknown       no
# 18                  219 sec         1     -1         0  unknown       no
# 19                   54 sec         1     -1         0  unknown       no
# 20                  262 sec         1     -1         0  unknown       no
# 21                  164 sec         1     -1         0  unknown       no
# 22                  160 sec         1     -1         0  unknown       no
# 23                  342 sec         1     -1         0  unknown       no
# 24                  181 sec         1     -1         0  unknown       no
# 25                  172 sec         1     -1         0  unknown       no
# 26                  296 sec         1     -1         0  unknown       no
# 27                  127 sec         1     -1         0  unknown       no
# 28                  255 sec         2     -1         0  unknown       no
# 29                  348 sec         1     -1         0  unknown       no
# ...                     ...       ...    ...       ...      ...      ...
# 45181  1.23333333333333 min         2    118         3  failure       no
# 45182  6.68333333333333 min         2    187         5  success      yes
# 45183               1.3 min         1     96         7  success       no
# 45184               2.3 min         1     22         5  success       no
# 45185  3.33333333333333 min         1     92         4  success      yes
# 45186  4.66666666666667 min         1    104         2  failure       no
# 45187              6.85 min         1     -1         0  unknown      yes
# 45188  3.93333333333333 min         1    550         2  success      yes
# 45189  2.88333333333333 min         1     92         5  failure       no
# 45190  3.43333333333333 min         1    188         3  success      yes
# 45191  4.36666666666667 min         1    183         1  failure      yes
# 45192  3.96666666666667 min         1     -1         0  unknown      yes
# 45193  7.48333333333333 min         2     33         4  success      yes
# 45194               2.7 min         2    187         5  failure       no
# 45195  3.53333333333333 min         1    187         6  success      yes
# 45196               5.5 min         1     -1         0  unknown      yes
# 45197               4.5 min         1     -1         0  unknown      yes
# 45198              5.55 min         2     -1         0  unknown       no
# 45199  19.4333333333333 min         3    530        12    other       no
# 45200  25.9333333333333 min         4     -1         0  unknown      yes
# 45201  3.76666666666667 min         1    184         4  success      yes
# 45202  3.73333333333333 min         1     -1         0  unknown      yes
# 45203  4.43333333333333 min         1     -1         0  unknown      yes
# 45204                 5 min         1     40         8  failure      yes
# 45205  6.43333333333333 min         2     -1         0  unknown      yes
# 45206  16.2833333333333 min         3     -1         0  unknown      yes
# 45207               7.6 min         2     -1         0  unknown      yes
# 45208  18.7833333333333 min         5    184         3  success      yes
# 45209  8.46666666666667 min         4     -1         0  unknown       no
# 45210  6.01666666666667 min         2    188        11    other       no
#
# [45211 rows x 19 columns]

# %% [markdown]
# **Following are the steps to be taken while Fixing Rows and Columns:**
# 1. Delete Summary Rows and Columns in the Dataset.
# 1. Delete Header and Footer Rows on every page.
# 1. Delete Extra Rows like blank rows, page numbers, etc.
# 1. We can merge different columns if it makes for better understanding of the data
# 1. Similarly, we can also split one column into multiple columns based on our requirements or understanding.
# 1. Add Column names, it is very important to have column names to the dataset.

# %% [markdown]
# Now if we observe the above dataset, the customerid column has of no importance to our analysis, and also the jobedu column has both the information of job and education in it.
#
# So, what we’ll do is, we’ll drop the customerid column and we’ll split the jobedu column into two other columns job and education and after that, we’ll drop the jobedu column as well.

# %%
data_again.isnull().sum()
# Out:
# customerid     0
# age           20
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# dtype: int64

# %% [markdown]
# * **Drop the missing values** – If the dataset is huge and missing values are very few then we can directly drop the values because it will not have much impact.
# * **Replace with mean values** – We can replace the missing values with mean values, but this is not advisable in case if the data has outliers.
# * **Replace with median values** – We can replace the missing values with median values, and it is recommended in case if the data has outliers.
# * **Replace with mode values** – We can replace the missing values with mode.

# %%
data_again.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
# customerid    45211 non-null int64
# age           45191 non-null float64
# salary        45211 non-null int64
# balance       45211 non-null int64
# marital       45211 non-null object
# jobedu        45211 non-null object
# targeted      45211 non-null object
# default       45211 non-null object
# housing       45211 non-null object
# loan          45211 non-null object
# contact       45211 non-null object
# day           45211 non-null int64
# month         45161 non-null object
# duration      45211 non-null object
# campaign      45211 non-null int64
# pdays         45211 non-null int64
# previous      45211 non-null int64
# poutcome      45211 non-null object
# response      45181 non-null object
# dtypes: float64(1), int64(7), object(11)
# memory usage: 6.6+ MB

# %%
mode = data_again['age'].mode().values[0]

print(mode)

data_again['age']= data_again['age'].replace(np.nan, mode)
# Out:
# 32.0

# %%
data_again.isnull().sum()
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response      30
# dtype: int64

# %%
data_again.shape
# Out:
# (45211, 19)

# %%
data_again["response"].fillna("no response", inplace = True) 
    
print(data_again.isnull().sum())
print(data_again.shape)
# Out:
# customerid     0
# age            0
# salary         0
# balance        0
# marital        0
# jobedu         0
# targeted       0
# default        0
# housing        0
# loan           0
# contact        0
# day            0
# month         50
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# response       0
# dtype: int64
# (45211, 19)

# %%
data_again = data_again.dropna(axis = 0, how ='any')
  
print(data_again.isnull().sum())
print(data_again.shape)
# Out:
# customerid    0
# age           0
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month         0
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response      0
# dtype: int64
# (45161, 19)

# %%
data_again.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# 1     -1         0  unknown       no
# 2     -1         0  unknown       no
# 3     -1         0  unknown       no
# 4     -1         0  unknown       no

# %%
data_again.drop('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_66715/75349668.py in <module>
# ----> 1 data_again.drop('')
#
# ~/.condahome/envs/Uni/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~/.condahome/envs/Uni/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# ~/.condahome/envs/Uni/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3141                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3142             else:
# -> 3143                 new_axis = axis.drop(labels, errors=errors)
#    3144             result = self.reindex(**{axis_name: new_axis})
#    3145
#
# ~/.condahome/envs/Uni/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    4402             if errors != 'ignore':
#    4403                 raise KeyError(
# -> 4404                     '{} not found in axis'.format(labels[mask]))
#    4405             indexer = indexer[~mask]
#    4406         return self.delete(indexer)
#
# KeyError: "[''] not found in axis"

# %% [markdown]
# **Lets start with plotting graphs**

# %%
plt.rcParams['figure.figsize'] = (25, 10)
sns.countplot(data_again['age'], palette = 'bright')
plt.title('Age',fontsize = 28)
plt.show()
# Out:
# /home/fenris/.condahome/envs/Uni/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.histplot(x='salary', data=data_again, )

plt.show()

# %%
plt.rcParams['figure.figsize'] = (25, 5)
sns.countplot(data_again['salary'], palette = 'bright')
plt.title('Salary',fontsize = 20)
plt.show()
# Out:
# /home/fenris/.condahome/envs/Uni/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Checking for Outliers

# %%
sns.boxplot(data_again['pdays'])
# Out:
# /home/fenris/.condahome/envs/Uni/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(data_again['balance'])
# Out:
# /home/fenris/.condahome/envs/Uni/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
